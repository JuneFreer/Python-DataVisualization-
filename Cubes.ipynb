# %%
import matplotlib.pyplot as plt
x_values = [1, 2, 3, 4, 5]
y_values = [x*x*x for x in x_values]

plt.scatter(x_values, y_values, s=20) #散点图 scatter

plt.title("Cube Numbers", fontsize=24)
plt.xlabel("Values", fontsize=14)
plt.ylabel("Cube of Values", fontsize=14)
plt.tick_params(axis='both', labelsize=14)

plt.show()

# %%
import matplotlib.pyplot as plt
x_values = list(range(1, 5001))
y_values = [x*x*x for x in x_values]

plt.scatter(x_values, y_values, linewidth=5)

plt.title("Cube Numbers", fontsize=24)
plt.xlabel("Values", fontsize=14)
plt.ylabel("Cube of Values", fontsize=14)
plt.tick_params(axis='both', labelsize=8)
plt.axis([0,5500,0,125000000000])

plt.show()

# %%
import matplotlib.pyplot as plt
x_values = [1, 2, 3, 4, 5]
y_values = [x*x*x for x in x_values]

plt.scatter(x_values, y_values, s=150, c=y_values, cmap=plt.cm.Reds) #散点图 scatter #colormap cmap 颜色映射
plt.title("Cube Numbers", fontsize=24) 
plt.xlabel("Values", fontsize=14)
plt.ylabel("Cube of Values", fontsize=14)
plt.tick_params(axis='both', labelsize=14)

plt.show()

# %%
import matplotlib.pyplot as plt
x_values = list(range(1, 5001))
y_values = [x*x*x for x in x_values]

plt.scatter(x_values, y_values, linewidth=5, c=y_values) #颜色映射 colormap cmap

plt.title("Cube Numbers", fontsize=24)
plt.xlabel("Values", fontsize=14)
plt.ylabel("Cube of Values", fontsize=14)
plt.tick_params(axis='both', labelsize=8)
plt.axis([0,5500,0,125000000000])

plt.show()
